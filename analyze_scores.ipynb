# %%
import music21
# Out:
#
# Music21 v.4 is the last version that will support Python 2.
# Please start using Python 3 instead.
#
# Set music21.environment.UserSettings()['warnings'] = 0
# to disable this message.

# %%
reload(music21)
score = music21.converter.parse("scores/mozart/k550-01.krn")

# %%
last_measure = score.measure(-1)
last_measure.show('ipython')
# Out:
# (<music21.metadata.primitives.Text object at 0x11a2178d0>, '<music21.metadata.primitives.Text object at 0x11a2178d0>', UnicodeDecodeError('utf8', '\xd6sterreich', 0, 1, 'invalid continuation byte'))
